# %%
import tensorflow as tf
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import cifar100

# %%
((X_train, y_train),(X_test, y_test)) = cifar100.load_data(label_mode="fine")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
num_image = 23
plt.imshow(X_train[num_image])
print(y_train[num_image])
# Out:
# [87]

# %%
# !wget --no-check-certificate https://storage.googleapis.com/platzi-tf2/cifar100_labels.json \
    -O /tmp/cifar100_labels.json
# Out:
# --2023-02-14 21:35:58--  https://storage.googleapis.com/platzi-tf2/cifar100_labels.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.214.128, 172.253.114.128, 108.177.111.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.214.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1436 (1.4K) [application/json]
# Saving to: ‘/tmp/cifar100_labels.json’
#
# /tmp/cifar100_label 100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2023-02-14 21:35:58 (18.8 MB/s) - ‘/tmp/cifar100_labels.json’ saved [1436/1436]

# %%
import json
with open("/tmp/cifar100_labels.json",'r') as fine_labels:
  cifar100_labels = json.load(fine_labels)

# %%
num_image = 73
plt.imshow(X_train[num_image])
print(cifar100_labels[y_train[num_image][0]])
# Out:
# tractor
